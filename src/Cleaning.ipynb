# %% [markdown]
# # Limpieza de archivos

# %%
import pandas as pd
import csv
pd.options.display.max_columns = None

import warnings
warnings.filterwarnings('ignore')

import re

# %%
torneos=pd.read_csv('../datanosubir/tennis_data.csv')

# %%
torneos.head()
# Out:
#    ATP  Location                Tournament        Date  Series    Court  \
# 0    1  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor
# 1    1  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor
# 2    1  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor
# 3    1  Adelaide  Adelaide International 1  2022-01-03  ATP250  Outdoor
# 4    1  Adelaide  Adelaide International 1  2022-01-04  ATP250  Outdoor
#
#   Surface      Round  Best of       Winner               Loser  WRank  LRank  \
# 0    Hard  1st Round        3    Kwon S.W.         Nishioka Y.   53.0   81.0
# 1    Hard  1st Round        3  Monteiro T.         Altmaier D.   89.0   84.0
# 2    Hard  1st Round        3     Djere L.  Carballes Baena R.   52.0   79.0
# 3    Hard  1st Round        3   Johnson S.            Vukic A.   85.0  156.0
# 4    Hard  1st Round        3    Moutet C.             Rune H.   92.0  103.0
#
# ...

# %%
torneos.shape
# Out:
# (36120, 54)

# %%
colseliminar=['Location','ATP','Best of','B365W','B365L','PSW','PSL','MaxW','MaxL','AvgW',
              'AvgL','EXW','EXL','LBW','LBL','SJW','SJL','UBW','UBL',
             'WPts','LPts','W1','L1','W2','L2','W3','L3','W4','L4','W5',
              'L5','Wsets','Lsets','pl1_year_pro','pl2_year_pro','Court','Comment','WRank','LRank']

torneos = torneos.drop(columns=colseliminar)

# %%
torneos.shape
# Out:
# (36120, 15)

# %%
nan_colums=torneos.isna().sum()
nan_colums
# Out:
# Tournament      0
# Date            0
# Series          0
# Surface         0
# Round           0
# Winner          0
# Loser           0
# pl1_flag       96
# pl1_weight     96
# pl1_height     96
# pl1_hand       96
# pl2_flag      649
# pl2_weight    649
# pl2_height    649
# pl2_hand      649
# dtype: int64

# %%
torneos.fillna({'LRank':0,'WRank':0}, inplace=True)

# %%
torneos.fillna({'pl1_flag':'unknown','pl1_hand':'unknown',
                'pl2_flag':'unknown','pl2_hand':'unknown'}, inplace=True)

# %%
cols = ['pl1_weight','pl1_height','pl2_weight', 'pl2_height']

torneos.loc[:,cols] = torneos.loc[:,cols].ffill()

# %%
torneos = torneos.astype({'pl1_weight': 'int','pl1_height': 'int','pl2_weight': 'int','pl2_height': 'int'})

# %%
torneos=torneos[torneos['Date'] >= '2018']

# %%
torneos.head()
# Out:
#                  Tournament        Date  Series Surface      Round  \
# 0  Adelaide International 1  2022-01-03  ATP250    Hard  1st Round
# 1  Adelaide International 1  2022-01-03  ATP250    Hard  1st Round
# 2  Adelaide International 1  2022-01-03  ATP250    Hard  1st Round
# 3  Adelaide International 1  2022-01-03  ATP250    Hard  1st Round
# 4  Adelaide International 1  2022-01-04  ATP250    Hard  1st Round
#
#         Winner               Loser pl1_flag  pl1_weight  pl1_height  \
# 0    Kwon S.W.         Nishioka Y.      KOR          72         180
# 1  Monteiro T.         Altmaier D.      BRA          78         183
# 2     Djere L.  Carballes Baena R.      SRB          80         185
# 3   Johnson S.            Vukic A.      USA          86         188
# 4    Moutet C.             Rune H.      FRA          71         175
#
#        pl1_hand pl2_flag  pl2_weight  pl2_height      pl2_hand
# 0  Right-Handed      JPN          64         170   Left-Handed
# ...

# %%
def nombre(x):
        
    if 'Medvedev' in x:
        
        return 'Daniil Medvedev'
    
    if 'Rublev' in x:
        
        return 'Andrey Rublev'
    
    if 'Fritz' in x:
        
        return 'Taylor Fritz'
    
    if 'Hurkacz' in x:
        
        return 'Hubert Hurkacz'
    
    if 'Djokovic' in x:
        
        return 'Novak Djokovic'  
    
    if 'Rune' in x:
        
        return 'Holger Rune'
    
    if 'Nadal' in x:
        
        return 'Rafael Nadal'         
        
    if 'Alcaraz' in x:
        
        return 'Carlos Alcaraz'
        
    if 'Ruud' in x:
        
        return 'Casper Ruud'
    
    if 'Aliassime' in x:
        
        return 'Felix Auger-Aliassime'
        
    if 'Tsitsipas' in x:
        
        return 'Stefanos Tsitsipas'
        
    if 'Zverev' in x:
        
        return 'Alexander Zverev'
        
    if 'Busta' in x:
        
        return 'Pablo Carreno Busta'
        
    if 'Norrie' in x:
        
        return 'Cameron Norrie'
    
    if 'Sinner' in x:
        
        return 'Jannik Sinner'
    
    if 'Berrettini' in x:
        
        return 'Matteo Berrettini'
    
    if 'Cilic' in x:
        
        return 'Marin Cilic'
    
    if 'Shapovalov' in x:
        
        return 'Denis Shapovalov'
    
    if 'Tiafoe' in x:
        
        return 'Frances Tiafoe'
    
    if 'Khachanov' in x:
        
        return 'Karen Khachanov'
    
    if 'Bautista' in x:
        
        return 'Roberto Bautista Agut'
    
    if 'Kyrgios' in x:
        
        return 'Nick Kyrgios'
    
    if 'Musetti' in x:
        
        return 'Lorenzo Musetti'
    
    if 'Minaur' in x:
        
        return 'Alex de Minaur'
    
    if 'Schwartzman' in x:
        
        return 'Diego Schwartzman'
    
    if 'Coric' in x:
        
        return 'Borna Coric'
    
    if 'Evans' in x:
        
        return 'Daniel Evans'
    
    if 'Dimitrov' in x:
        
        return 'Grigor Dimitrov'
    
    if 'Kecmanovic' in x:
        
        return 'Miomir Kecmanovic'
    
    if 'Cerundolo' in x:
        
        return 'Francisco Cerundolo'
    
    if 'Fokina' in x:
        
        return 'Alejandro Davidovich Fokina'
    
    if 'Paul' in x:
        
        return 'Tommy Paul' 
    
    else:
        
        return x

# %%
torneos.Winner = torneos.Winner.apply(nombre)

# %%
torneos.Loser = torneos.Loser.apply(nombre)

# %%
torneos=torneos[(torneos['Winner'] == 'Carlos Alcaraz') | (torneos['Winner'] == 'Casper Ruud')
               | (torneos['Winner'] == 'Rafael Nadal') | (torneos['Winner'] == 'Stefanos Tsitsipas')
               | (torneos['Winner'] == 'Felix Auger-Aliassime') | (torneos['Winner'] == 'Daniil Medvedev')
               | (torneos['Winner'] == 'Andrey Rublev') | (torneos['Winner'] == 'Taylor Fritz')
               | (torneos['Winner'] == 'Hubert Hurkacz') | (torneos['Winner'] == 'Novak Djokovic')
               | (torneos['Winner'] == 'Holger Rune') | (torneos['Winner'] == 'Alexander Zverev')
               | (torneos['Winner'] == 'Pablo Carreno Busta') | (torneos['Winner'] == 'Cameron Norrie')
               | (torneos['Winner'] == 'Jannik Sinner') | (torneos['Winner'] == 'Matteo Berrettini')
               | (torneos['Winner'] == 'Marin Cilic') | (torneos['Winner'] == 'Denis Shapovalov')
               | (torneos['Winner'] == 'Frances Tiafoe') | (torneos['Winner'] == 'Karen Khachanov')
               | (torneos['Winner'] == 'Roberto Bautista Agut') | (torneos['Winner'] == 'Nick Kyrgios')
               | (torneos['Winner'] == 'Lorenzo Musetti') | (torneos['Winner'] == 'Alex de Minaur')
               | (torneos['Winner'] == 'Diego Schwartzman') | (torneos['Winner'] == 'Borna Coric')                                             
               | (torneos['Winner'] == 'Daniel Evans') | (torneos['Winner'] == 'Grigor Dimitrov')
               | (torneos['Winner'] == 'Miomir Kecmanovic') | (torneos['Winner'] == 'Francisco Cerundolo')
               | (torneos['Winner'] == 'Alejandro Davidovich Fokina') | (torneos['Winner'] == 'Tommy Paul')]

# %%
 torneos=torneos[(torneos['Loser'] == 'Carlos Alcaraz') | (torneos['Loser'] == 'Casper Ruud')
               | (torneos['Loser'] == 'Rafael Nadal') | (torneos['Loser'] == 'Stefanos Tsitsipas')
               | (torneos['Loser'] == 'Felix Auger-Aliassime') | (torneos['Loser'] == 'Daniil Medvedev')
               | (torneos['Loser'] == 'Andrey Rublev') | (torneos['Loser'] == 'Taylor Fritz')
               | (torneos['Loser'] == 'Hubert Hurkacz') | (torneos['Loser'] == 'Novak Djokovic')
               | (torneos['Loser'] == 'Holger Rune') | (torneos['Loser'] == 'Alexander Zverev')
               | (torneos['Loser'] == 'Pablo Carreno Busta') | (torneos['Loser'] == 'Cameron Norrie')
               | (torneos['Loser'] == 'Jannik Sinner') | (torneos['Loser'] == 'Matteo Berrettini')
               | (torneos['Loser'] == 'Marin Cilic') | (torneos['Loser'] == 'Denis Shapovalov')
               | (torneos['Loser'] == 'Frances Tiafoe') | (torneos['Loser'] == 'Karen Khachanov')
               | (torneos['Loser'] == 'Frances Tiafoe') | (torneos['Loser'] == 'Karen Khachanov')
               | (torneos['Loser'] == 'Roberto Bautista Agut') | (torneos['Loser'] == 'Nick Kyrgios')
               | (torneos['Loser'] == 'Lorenzo Musetti') | (torneos['Loser'] == 'Alex de Minaur')
               | (torneos['Loser'] == 'Diego Schwartzman') | (torneos['Loser'] == 'Borna Coric')                                             
               | (torneos['Loser'] == 'Daniel Evans') | (torneos['Loser'] == 'Grigor Dimitrov')
               | (torneos['Loser'] == 'Miomir Kecmanovic') | (torneos['Loser'] == 'Francisco Cerundolo')
               | (torneos['Loser'] == 'Alejandro Davidovich Fokina') | (torneos['Loser'] == 'Tommy Paul')]

# %%
torneos.head()
# Out:
#                    Tournament        Date      Series Surface          Round  \
# 24   Adelaide International 1  2022-01-08      ATP250    Hard     Semifinals
# 55   Adelaide International 2  2022-01-10      ATP250    Hard      1st Round
# 75   Adelaide International 2  2022-01-13      ATP250    Hard  Quarterfinals
# 169           Australian Open  2022-01-18  Grand Slam    Hard      1st Round
# 173           Australian Open  2022-01-19  Grand Slam    Hard      2nd Round
#
#                 Winner            Loser pl1_flag  pl1_weight  pl1_height  \
# 24     Karen Khachanov      Marin Cilic      RUS          88         198
# 55          Tommy Paul   Frances Tiafoe      USA          78         185
# 75         Marin Cilic       Tommy Paul      CRO          89         198
# 169     Alex de Minaur  Lorenzo Musetti      AUS          69         180
# 173  Miomir Kecmanovic       Tommy Paul      SRB          75         183
#
# ...

# %%
torneos.to_csv('../data/torneosclean.csv', index=False)

# %%
torneostotal=pd.read_csv('../data/torneosclean.csv')

# %%
rolandgarros=pd.read_excel('../torneos22/RolandGarros.xlsx')

# %%
rolandgarros.columns = rolandgarros.iloc[0]

rolandgarros=rolandgarros.drop([0],axis=0)

# %%
rolandgarros.head()
# Out:
# 0   Tournament        Date      Series Surface          Round  \
# 1  French Open  2022-05-22  Grand Slam    Clay      The Final
# 2  French Open  2022-05-22  Grand Slam    Clay     Semifinals
# 3  French Open  2022-05-22  Grand Slam    Clay     Semifinals
# 4  French Open  2022-05-22  Grand Slam    Clay  Quarterfinals
# 5  French Open  2022-05-22  Grand Slam    Clay  Quarterfinals
#
# 0            Winner             Loser pl1_flag pl1_weight pl1_height pl1_hand  \
# 1      Rafael Nadal       Casper Ruud      NaN        NaN        NaN      NaN
# 2      Rafael Nadal  Alexander Zverev      NaN        NaN        NaN      NaN
# 3       Casper Ruud       Marin Cilic      NaN        NaN        NaN      NaN
# 4      Rafael Nadal    Novak Djokovic      NaN        NaN        NaN      NaN
# 5  Alexander Zverev    Carlos Alcaraz      NaN        NaN        NaN      NaN
#
# 0 pl2_flag pl2_weight pl2_height pl2_hand
# 1      NaN        NaN        NaN      NaN
# ...

# %%
wimbledon=pd.read_excel('../torneos22/Wimbledon.xlsx')

# %%
wimbledon.columns = wimbledon.iloc[0]

wimbledon=wimbledon.drop([0],axis=0)

# %%
usopen=pd.read_excel('../torneos22/US Open.xlsx')

# %%
usopen.columns = usopen.iloc[0]

usopen=usopen.drop([0],axis=0)

# %%
mutuamad=pd.read_excel('../torneos22/MtuaMadrileñaOpen.xlsx')

# %%
mutuamad.columns = mutuamad.iloc[0]

mutuamad=mutuamad.drop([0],axis=0)

# %%
montecarlo=pd.read_excel('../torneos22/MonteCarloOpen.xlsx')

# %%
montecarlo.columns = montecarlo.iloc[0]

montecarlo=montecarlo.drop([0],axis=0)

# %%
miami=pd.read_excel('../torneos22/MiamiOpen.xlsx')

# %%
miami.columns = miami.iloc[0]

miami=miami.drop([0],axis=0)

# %%
roma=pd.read_excel('../torneos22/MastersRoma.xlsx')

# %%
roma.columns = roma.iloc[0]

roma=roma.drop([0],axis=0)

# %%
paris=pd.read_excel('../torneos22/MastersRolexParis.xlsx')

# %%
paris.columns = paris.iloc[0]

paris=paris.drop([0],axis=0)

# %%
montreal=pd.read_excel('../torneos22/MastersMontreal.xlsx')

# %%
montreal.columns = montreal.iloc[0]

montreal=montreal.drop([0],axis=0)

# %%
cincinnati=pd.read_excel('../torneos22/MastersCincinnati.xlsx')

# %%
cincinnati.columns = cincinnati.iloc[0]

cincinnati=cincinnati.drop([0],axis=0)

# %%
indian=pd.read_excel('../torneos22/IndianWells.xlsx')

# %%
indian.columns = indian.iloc[0]

indian=indian.drop([0],axis=0)

# %%
alltorneos = pd.concat([paris,usopen,cincinnati,montreal,wimbledon,rolandgarros,roma,
                        mutuamad,montecarlo,miami,indian,torneostotal],axis=0)

# %%
eliminarcolum=['pl1_flag','pl1_weight','pl1_height','pl1_hand','pl2_flag','pl2_weight','pl2_height','pl2_hand']


alltorneos = alltorneos.drop(columns=eliminarcolum)

# %%
def hora(x):
    
    return (str(x)[:10])

# %%
alltorneos.Date=alltorneos.Date.apply(hora)

# %%
alltorneos.to_csv('../data/Alltorneos.csv', index=False)

# %%
dfsaquetierra52Week=pd.read_csv('../datanosubir/dfsaquetierra52Week.csv')
dfsaquetierra2021=pd.read_csv('../datanosubir/dfsaquetierra2021.csv')
dfsaquetierra2020=pd.read_csv('../datanosubir/dfsaquetierra2020.csv')
dfsaquetierra2019=pd.read_csv('../datanosubir/dfsaquetierra2019.csv')
dfsaquetierra2018=pd.read_csv('../datanosubir/dfsaquetierra2018.csv')

dfsaquedura52Week=pd.read_csv('../datanosubir/dfsaquedura52Week.csv')
dfsaquedura2021=pd.read_csv('../datanosubir/dfsaquedura2021.csv')
dfsaquedura2020=pd.read_csv('../datanosubir/dfsaquedura2020.csv')
dfsaquedura2019=pd.read_csv('../datanosubir/dfsaquedura2019.csv')
dfsaquedura2018=pd.read_csv('../datanosubir/dfsaquedura2018.csv')

dfsaquehierba52Week=pd.read_csv('../datanosubir/dfsaquehierba52Week.csv')
dfsaquehierba2021=pd.read_csv('../datanosubir/dfsaquehierba2021.csv')
dfsaquehierba2019=pd.read_csv('../datanosubir/dfsaquehierba2019.csv')
dfsaquehierba2018=pd.read_csv('../datanosubir/dfsaquehierba2018.csv')

dfrestotierra52Week=pd.read_csv('../datanosubir/dfrestotierra52Week.csv')
dfrestotierra2021=pd.read_csv('../datanosubir/dfrestotierra2021.csv')
dfrestotierra2020=pd.read_csv('../datanosubir/dfrestotierra2020.csv')
dfrestotierra2019=pd.read_csv('../datanosubir/dfrestotierra2019.csv')
dfrestotierra2018=pd.read_csv('../datanosubir/dfrestotierra2018.csv')

dfrestodura52Week=pd.read_csv('../datanosubir/dfrestodura52Week.csv')
dfrestodura2021=pd.read_csv('../datanosubir/dfrestodura2021.csv')
dfrestodura2020=pd.read_csv('../datanosubir/dfrestodura2020.csv')
dfrestodura2019=pd.read_csv('../datanosubir/dfrestodura2019.csv')
dfrestodura2018=pd.read_csv('../datanosubir/dfrestodura2018.csv')

dfrestohierba52Week=pd.read_csv('../datanosubir/dfrestohierba52Week.csv')
dfrestohierba2021=pd.read_csv('../datanosubir/dfrestohierba2021.csv')
dfrestohierba2019=pd.read_csv('../datanosubir/dfrestohierba2019.csv')
dfrestohierba2018=pd.read_csv('../datanosubir/dfrestohierba2018.csv')

dfpresiontierra52Week=pd.read_csv('../datanosubir/dfpresiontierra52Week.csv')
dfpresiontierra2021=pd.read_csv('../datanosubir/dfpresiontierra2021.csv')
dfpresiontierra2020=pd.read_csv('../datanosubir/dfpresiontierra2020.csv')
dfpresiontierra2019=pd.read_csv('../datanosubir/dfpresiontierra2019.csv')
dfpresiontierra2018=pd.read_csv('../datanosubir/dfpresiontierra2018.csv')

dfpresiondura52Week=pd.read_csv('../datanosubir/dfpresiondura52Week.csv')
dfpresiondura2021=pd.read_csv('../datanosubir/dfpresiondura2021.csv')
dfpresiondura2020=pd.read_csv('../datanosubir/dfpresiondura2020.csv')
dfpresiondura2019=pd.read_csv('../datanosubir/dfpresiondura2019.csv')
dfpresiondura2018=pd.read_csv('../datanosubir/dfpresiondura2018.csv')

dfpresionhierba52Week=pd.read_csv('../datanosubir/dfpresionhierba52Week.csv')
dfpresionhierba2021=pd.read_csv('../datanosubir/dfpresionhierba2021.csv')
dfpresionhierba2019=pd.read_csv('../datanosubir/dfpresionhierba2019.csv')
dfpresionhierba2018=pd.read_csv('../datanosubir/dfpresionhierba2018.csv')

# %%
saque = {'dfsaquetierra52Week': dfsaquetierra52Week, 'dfsaquetierra2021': dfsaquetierra2021, 
             'dfsaquetierra2020': dfsaquetierra2020, 'dfsaquetierra2019': dfsaquetierra2019, 
             'dfsaquetierra2018': dfsaquetierra2018, 'dfsaquedura52Week': dfsaquedura52Week, 
             'dfsaquedura2021': dfsaquedura2021, 'dfsaquedura2020': dfsaquedura2020, 
             'dfsaquedura2019': dfsaquedura2019, 'dfsaquedura2018': dfsaquedura2019,
             'dfsaquehierba52Week': dfsaquehierba52Week, 'dfsaquehierba2021': dfsaquehierba2021, 
             'dfsaquehierba2019': dfsaquehierba2019, 'dfsaquehierba2018': dfsaquehierba2018}

saque1={}

for k,v in saque.items():
    
    v=v[ (v['Jugador'] == 'Rafael Nadal') 
       | (v['Jugador'] == 'Carlos Alcaraz') 
       | (v['Jugador'] == 'Casper Ruud')
       | (v['Jugador'] == 'Stefanos Tsitsipas')
       | (v['Jugador'] == 'Felix Auger-Aliassime')
       | (v['Jugador'] == 'Daniil Medvedev')
       | (v['Jugador'] == 'Andrey Rublev')
       | (v['Jugador'] == 'Taylor Fritz')
       | (v['Jugador'] == 'Hubert Hurkacz')
       | (v['Jugador'] == 'Novak Djokovic')
       | (v['Jugador'] == 'Holger Rune') 
       | (v['Jugador'] == 'Alexander Zverev')
       | (v['Jugador'] == 'Pablo Carreno Busta')
       | (v['Jugador'] == 'Cameron Norrie')
       | (v['Jugador'] == 'Jannik Sinner')
       | (v['Jugador'] == 'Matteo Berrettini')
       | (v['Jugador'] == 'Marin Cilic')
       | (v['Jugador'] == 'Denis Shapovalov') 
       | (v['Jugador'] == 'Frances Tiafoe')
       | (v['Jugador'] == 'Karen Khachanov')
       | (v['Jugador'] == 'Roberto Bautista Agut') 
       | (v['Jugador'] == 'Nick Kyrgios')
       | (v['Jugador'] == 'Lorenzo Musetti')
       | (v['Jugador'] == 'Alex de Minaur')
       | (v['Jugador'] == 'Diego Schwartzman')
       | (v['Jugador'] == 'Borna Coric')
       | (v['Jugador'] == 'Daniel Evans')
       | (v['Jugador'] == 'Grigor Dimitrov') 
       | (v['Jugador'] == 'Miomir Kecmanovic')
       | (v['Jugador'] == 'Francisco Cerundolo')
       | (v['Jugador'] == 'Alejandro Davidovich Fokina') 
       | (v['Jugador'] == 'Tommy Paul')]
    
    saque1.update({k:v})

# %%
resto = {'dfrestotierra52Week': dfrestotierra52Week, 'dfrestotierra2021': dfrestotierra2021, 
             'dfrestotierra2020': dfrestotierra2020, 'dfrestotierra2019': dfrestotierra2019, 
             'dfrestotierra2018': dfrestotierra2018, 'dfrestodura52Week': dfrestodura52Week, 
             'dfrestodura2021': dfrestodura2021, 'dfrestodura2020': dfrestodura2020, 
             'dfrestodura2019': dfrestodura2019, 'dfrestodura2018': dfrestodura2019,
             'dfrestohierba52Week': dfrestohierba52Week, 'dfrestohierba2021': dfrestohierba2021, 
             'dfrestohierba2019': dfrestohierba2019, 'dfrestohierba2018': dfrestohierba2018}

resto1={}

for k,v in resto.items():
    
    v=v[ (v['Jugador'] == 'Rafael Nadal') 
       | (v['Jugador'] == 'Carlos Alcaraz') 
       | (v['Jugador'] == 'Casper Ruud')
       | (v['Jugador'] == 'Stefanos Tsitsipas')
       | (v['Jugador'] == 'Felix Auger-Aliassime')
       | (v['Jugador'] == 'Daniil Medvedev')
       | (v['Jugador'] == 'Andrey Rublev')
       | (v['Jugador'] == 'Taylor Fritz')
       | (v['Jugador'] == 'Hubert Hurkacz')
       | (v['Jugador'] == 'Novak Djokovic')
       | (v['Jugador'] == 'Holger Rune') 
       | (v['Jugador'] == 'Alexander Zverev')
       | (v['Jugador'] == 'Pablo Carreno Busta')
       | (v['Jugador'] == 'Cameron Norrie')
       | (v['Jugador'] == 'Jannik Sinner')
       | (v['Jugador'] == 'Matteo Berrettini')
       | (v['Jugador'] == 'Marin Cilic')
       | (v['Jugador'] == 'Denis Shapovalov') 
       | (v['Jugador'] == 'Frances Tiafoe')
       | (v['Jugador'] == 'Karen Khachanov')
       | (v['Jugador'] == 'Roberto Bautista Agut') 
       | (v['Jugador'] == 'Nick Kyrgios')
       | (v['Jugador'] == 'Lorenzo Musetti')
       | (v['Jugador'] == 'Alex de Minaur')
       | (v['Jugador'] == 'Diego Schwartzman')
       | (v['Jugador'] == 'Borna Coric')
       | (v['Jugador'] == 'Daniel Evans')
       | (v['Jugador'] == 'Grigor Dimitrov') 
       | (v['Jugador'] == 'Miomir Kecmanovic')
       | (v['Jugador'] == 'Francisco Cerundolo')
       | (v['Jugador'] == 'Alejandro Davidovich Fokina') 
       | (v['Jugador'] == 'Tommy Paul')]
    
    resto1.update({k:v})

# %%
presion = {'dfpresiontierra52Week': dfpresiontierra52Week, 'dfpresiontierra2021': dfpresiontierra2021, 
             'dfpresiontierra2020': dfpresiontierra2020, 'dfpresiontierra2019': dfpresiontierra2019, 
             'dfpresiontierra2018': dfpresiontierra2018, 'dfpresiondura52Week': dfpresiondura52Week, 
             'dfpresiondura2021': dfpresiondura2021, 'dfpresiondura2020': dfpresiondura2020, 
             'dfpresiondura2019': dfpresiondura2019, 'dfpresiondura2018': dfpresiondura2019,
             'dfpresionhierba52Week': dfpresionhierba52Week, 'dfpresionhierba2021': dfpresionhierba2021, 
             'dfpresionhierba2019': dfpresionhierba2019, 'dfpresionhierba2018': dfpresionhierba2018}

presion1={}

for k,v in presion.items():
    
    v=v[ (v['Jugador'] == 'Rafael Nadal') 
       | (v['Jugador'] == 'Carlos Alcaraz') 
       | (v['Jugador'] == 'Casper Ruud')
       | (v['Jugador'] == 'Stefanos Tsitsipas')
       | (v['Jugador'] == 'Felix Auger-Aliassime')
       | (v['Jugador'] == 'Daniil Medvedev')
       | (v['Jugador'] == 'Andrey Rublev')
       | (v['Jugador'] == 'Taylor Fritz')
       | (v['Jugador'] == 'Hubert Hurkacz')
       | (v['Jugador'] == 'Novak Djokovic')
       | (v['Jugador'] == 'Holger Rune') 
       | (v['Jugador'] == 'Alexander Zverev')
       | (v['Jugador'] == 'Pablo Carreno Busta')
       | (v['Jugador'] == 'Cameron Norrie')
       | (v['Jugador'] == 'Jannik Sinner')
       | (v['Jugador'] == 'Matteo Berrettini')
       | (v['Jugador'] == 'Marin Cilic')
       | (v['Jugador'] == 'Denis Shapovalov') 
       | (v['Jugador'] == 'Frances Tiafoe')
       | (v['Jugador'] == 'Karen Khachanov')
       | (v['Jugador'] == 'Roberto Bautista Agut') 
       | (v['Jugador'] == 'Nick Kyrgios')
       | (v['Jugador'] == 'Lorenzo Musetti')
       | (v['Jugador'] == 'Alex de Minaur')
       | (v['Jugador'] == 'Diego Schwartzman')
       | (v['Jugador'] == 'Borna Coric')
       | (v['Jugador'] == 'Daniel Evans')
       | (v['Jugador'] == 'Grigor Dimitrov') 
       | (v['Jugador'] == 'Miomir Kecmanovic')
       | (v['Jugador'] == 'Francisco Cerundolo')
       | (v['Jugador'] == 'Alejandro Davidovich Fokina') 
       | (v['Jugador'] == 'Tommy Paul')]
    
    presion1.update({k:v})

# %%
namecols=['Ranking_Efectividad_Saque', 'Jugador','Efectividad_al_saque','Primer_Servicio_Saque_pct',
              'Puntos_Ganados_Primer_Saque_pct','Puntos_Ganados_Segundo_Saque_pct','Games_Ganados_Saque_pct',
              'Prom_AcesxPartido','Prom_DoblexPartido']

for v in saque1.values():
       
        v.columns=namecols

# %%
namecols=['Ranking_Efectividad_Resto', 'Jugador','Efectividad_al_resto','Restos_Primer_Saque_pct',
          'Restos_Segundo_Saque_pct','Games_Resto_pct',
          'Break_Points_Covertidos_pct']


for v in resto1.values():

    v.columns=namecols

# %%
namecols=['Ranking_Efectividad_Bajo_Presion', 'Jugador','Efectividad_bajo_presion','Break_Points_Covertidos_pct',
          'Break_Points_Salvados_pct','Tie_Break_Ganados_pct','Victorias_Sets_Definitivos_pct']


for v in presion1.values():

    v.columns=namecols

# %%
import re

def limpiezapct(x):
    
    palabra=re.findall('\d+\.\d', x)
    
    return ''.join(palabra)

# %%
for v in saque1.values():

        
    cols_pct = ['Primer_Servicio_Saque_pct','Puntos_Ganados_Primer_Saque_pct',
                'Puntos_Ganados_Segundo_Saque_pct','Games_Ganados_Saque_pct']

    for i in cols_pct:

        v[i]=v[i].apply(limpiezapct)

# %%
for v in resto1.values():

        
    cols_pct = ['Restos_Primer_Saque_pct', 'Restos_Segundo_Saque_pct',
                'Games_Resto_pct','Break_Points_Covertidos_pct']

    for i in cols_pct:

        v[i]=v[i].apply(limpiezapct)

# %%
for v in presion1.values():

        
    cols_pct = ['Break_Points_Covertidos_pct', 'Break_Points_Salvados_pct',
                'Tie_Break_Ganados_pct','Victorias_Sets_Definitivos_pct']

    for i in cols_pct:

        v[i]=v[i].apply(limpiezapct)

# %%
for v in saque1.values():
    
    v['Ranking_Efectividad_Saque'] = v['Ranking_Efectividad_Saque'].astype('int')

# %%
for v in saque1.values():
    
    v = v.astype({'Efectividad_al_saque': 'float', 'Primer_Servicio_Saque_pct': 'float',
                      'Puntos_Ganados_Primer_Saque_pct': 'float','Puntos_Ganados_Segundo_Saque_pct': 'float', 
                      'Games_Ganados_Saque_pct': 'float','Prom_AcesxPartido': 'float',
                      'Prom_DoblexPartido': 'float'})

# %%
for v in resto1.values():
    
    v['Ranking_Efectividad_Resto'] = v['Ranking_Efectividad_Resto'].astype('int')

# %%
for v in resto1.values():
    
    v = v.astype({'Efectividad_al_resto': 'float', 'Restos_Primer_Saque_pct': 'float',
                      'Restos_Segundo_Saque_pct': 'float','Games_Resto_pct': 'float', 
                      'Break_Points_Covertidos_pct': 'float'})

# %%
for v in presion1.values():
    
    v['Ranking_Efectividad_Bajo_Presion'] = v['Ranking_Efectividad_Bajo_Presion'].astype('int')

# %%
for v in presion1.values():
    
    v = v.astype({'Efectividad_bajo_presion': 'float', 'Break_Points_Covertidos_pct': 'float',
                      'Break_Points_Salvados_pct': 'float','Tie_Break_Ganados_pct': 'float', 
                      'Victorias_Sets_Definitivos_pct': 'float'})

# %%
for k,v in presion1.items():
    
    v.to_csv(f'../data/{k}.csv', index=False)

# %%
for k,v in resto1.items():
    
    v.to_csv(f'../data/{k}.csv', index=False)

# %%
for k,v in saque1.items():
    
    v.to_csv(f'../data/{k}.csv', index=False)

# %%
dfsaquetierra52Week=pd.read_csv('../data/dfsaquetierra52Week.csv')
dfsaquetierra2021=pd.read_csv('../data/dfsaquetierra2021.csv')
dfsaquetierra2020=pd.read_csv('../data/dfsaquetierra2020.csv')
dfsaquetierra2019=pd.read_csv('../data/dfsaquetierra2019.csv')
dfsaquetierra2018=pd.read_csv('../data/dfsaquetierra2018.csv')

dfsaquedura52Week=pd.read_csv('../data/dfsaquedura52Week.csv')
dfsaquedura2021=pd.read_csv('../data/dfsaquedura2021.csv')
dfsaquedura2020=pd.read_csv('../data/dfsaquedura2020.csv')
dfsaquedura2019=pd.read_csv('../data/dfsaquedura2019.csv')
dfsaquedura2018=pd.read_csv('../data/dfsaquedura2018.csv')

dfsaquehierba52Week=pd.read_csv('../data/dfsaquehierba52Week.csv')
dfsaquehierba2021=pd.read_csv('../data/dfsaquehierba2021.csv')
dfsaquehierba2019=pd.read_csv('../data/dfsaquehierba2019.csv')
dfsaquehierba2018=pd.read_csv('../data/dfsaquehierba2018.csv')

dfrestotierra52Week=pd.read_csv('../data/dfrestotierra52Week.csv')
dfrestotierra2021=pd.read_csv('../data/dfrestotierra2021.csv')
dfrestotierra2020=pd.read_csv('../data/dfrestotierra2020.csv')
dfrestotierra2019=pd.read_csv('../data/dfrestotierra2019.csv')
dfrestotierra2018=pd.read_csv('../data/dfrestotierra2018.csv')

dfrestodura52Week=pd.read_csv('../data/dfrestodura52Week.csv')
dfrestodura2021=pd.read_csv('../data/dfrestodura2021.csv')
dfrestodura2020=pd.read_csv('../data/dfrestodura2020.csv')
dfrestodura2019=pd.read_csv('../data/dfrestodura2019.csv')
dfrestodura2018=pd.read_csv('../data/dfrestodura2018.csv')

dfrestohierba52Week=pd.read_csv('../data/dfrestohierba52Week.csv')
dfrestohierba2021=pd.read_csv('../data/dfrestohierba2021.csv')
dfrestohierba2019=pd.read_csv('../data/dfrestohierba2019.csv')
dfrestohierba2018=pd.read_csv('../data/dfrestohierba2018.csv')

dfpresiontierra52Week=pd.read_csv('../data/dfpresiontierra52Week.csv')
dfpresiontierra2021=pd.read_csv('../data/dfpresiontierra2021.csv')
dfpresiontierra2020=pd.read_csv('../data/dfpresiontierra2020.csv')
dfpresiontierra2019=pd.read_csv('../data/dfpresiontierra2019.csv')
dfpresiontierra2018=pd.read_csv('../data/dfpresiontierra2018.csv')

dfpresiondura52Week=pd.read_csv('../data/dfpresiondura52Week.csv')
dfpresiondura2021=pd.read_csv('../data/dfpresiondura2021.csv')
dfpresiondura2020=pd.read_csv('../data/dfpresiondura2020.csv')
dfpresiondura2019=pd.read_csv('../data/dfpresiondura2019.csv')
dfpresiondura2018=pd.read_csv('../data/dfpresiondura2018.csv')

dfpresionhierba52Week=pd.read_csv('../data/dfpresionhierba52Week.csv')
dfpresionhierba2021=pd.read_csv('../data/dfpresionhierba2021.csv')
dfpresionhierba2019=pd.read_csv('../data/dfpresionhierba2019.csv')
dfpresionhierba2018=pd.read_csv('../data/dfpresionhierba2018.csv')

# %%
dfsaquetierra52Week['Año']=""
dfsaquetierra2021['Año']=""
dfsaquetierra2020['Año']=""
dfsaquetierra2019['Año']=""
dfsaquetierra2018['Año']=""

dfsaquedura52Week['Año']=""
dfsaquedura2021['Año']=""
dfsaquedura2020['Año']=""
dfsaquedura2019['Año']=""
dfsaquedura2018['Año']=""

dfsaquehierba52Week['Año']=""
dfsaquehierba2021['Año']=""
dfsaquehierba2019['Año']=""
dfsaquehierba2018['Año']=""

dfrestotierra52Week['Año']=""
dfrestotierra2021['Año']=""
dfrestotierra2020['Año']=""
dfrestotierra2019['Año']=""
dfrestotierra2018['Año']=""

dfrestodura52Week['Año']=""
dfrestodura2021['Año']=""
dfrestodura2020['Año']=""
dfrestodura2019['Año']=""
dfrestodura2018['Año']=""

dfrestohierba52Week['Año']=""
dfrestohierba2021['Año']=""
dfrestohierba2019['Año']=""
dfrestohierba2018['Año']=""

dfpresiontierra52Week['Año']=""
dfpresiontierra2021['Año']=""
dfpresiontierra2020['Año']=""
dfpresiontierra2019['Año']=""
dfpresiontierra2018['Año']=""

dfpresiondura52Week['Año']=""
dfpresiondura2021['Año']=""
dfpresiondura2020['Año']=""
dfpresiondura2019['Año']=""
dfpresiondura2018['Año']=""

dfpresionhierba52Week['Año']=""
dfpresionhierba2021['Año']=""
dfpresionhierba2019['Año']=""
dfpresionhierba2018['Año']=""

# %%
dfsaquetierra52Week['Superficie']=""
dfsaquetierra2021['Superficie']=""
dfsaquetierra2020['Superficie']=""
dfsaquetierra2019['Superficie']=""
dfsaquetierra2018['Superficie']=""

dfsaquedura52Week['Superficie']=""
dfsaquedura2021['Superficie']=""
dfsaquedura2020['Superficie']=""
dfsaquedura2019['Superficie']=""
dfsaquedura2018['Superficie']=""

dfsaquehierba52Week['Superficie']=""
dfsaquehierba2021['Superficie']=""
dfsaquehierba2019['Superficie']=""
dfsaquehierba2018['Superficie']=""

dfrestotierra52Week['Superficie']=""
dfrestotierra2021['Superficie']=""
dfrestotierra2020['Superficie']=""
dfrestotierra2019['Superficie']=""
dfrestotierra2018['Superficie']=""

dfrestodura52Week['Superficie']=""
dfrestodura2021['Superficie']=""
dfrestodura2020['Superficie']=""
dfrestodura2019['Superficie']=""
dfrestodura2018['Superficie']=""

dfrestohierba52Week['Superficie']=""
dfrestohierba2021['Superficie']=""
dfrestohierba2019['Superficie']=""
dfrestohierba2018['Superficie']=""

dfpresiontierra52Week['Superficie']=""
dfpresiontierra2021['Superficie']=""
dfpresiontierra2020['Superficie']=""
dfpresiontierra2019['Superficie']=""
dfpresiontierra2018['Superficie']=""

dfpresiondura52Week['Superficie']=""
dfpresiondura2021['Superficie']=""
dfpresiondura2020['Superficie']=""
dfpresiondura2019['Superficie']=""
dfpresiondura2018['Superficie']=""

dfpresionhierba52Week['Superficie']=""
dfpresionhierba2021['Superficie']=""
dfpresionhierba2019['Superficie']=""
dfpresionhierba2018['Superficie']=""

# %%
def año1(x):
    
    if x=='':
        
        return 2022

# %%
def año2(x):
    
    if x=='':
        
        return 2021

# %%
def año3(x):
    
    if x=='':
        
        return 2020

# %%
def año4(x):
    
    if x=='':
        
        return 2019

# %%
def año5(x):
    
    if x=='':
        
        return 2018

# %%
def superficie1(x):
    
    if x=='':
        
        return 'Hard'

# %%
def superficie2(x):
    
    if x=='':
        
        return 'Clay'

# %%
def superficie3(x):
    
    if x=='':
        
        return 'Grass'

# %%
dfsaquetierra52Week['Año']=dfsaquetierra52Week['Año'].apply(año1)
dfsaquetierra2021['Año']=dfsaquetierra2021['Año'].apply(año2)
dfsaquetierra2020['Año']=dfsaquetierra2020['Año'].apply(año3)
dfsaquetierra2019['Año']=dfsaquetierra2019['Año'].apply(año4)
dfsaquetierra2018['Año']=dfsaquetierra2018['Año'].apply(año5)

dfsaquedura52Week['Año']=dfsaquedura52Week['Año'].apply(año1)
dfsaquedura2021['Año']=dfsaquedura2021['Año'].apply(año2)
dfsaquedura2020['Año']=dfsaquedura2020['Año'].apply(año3)
dfsaquedura2019['Año']=dfsaquedura2019['Año'].apply(año4)
dfsaquedura2018['Año']=dfsaquedura2018['Año'].apply(año5)

dfsaquehierba52Week['Año']=dfsaquehierba52Week['Año'].apply(año1)
dfsaquehierba2021['Año']=dfsaquehierba2021['Año'].apply(año2)
dfsaquehierba2019['Año']=dfsaquehierba2019['Año'].apply(año4)
dfsaquehierba2018['Año']=dfsaquehierba2018['Año'].apply(año5)

dfrestotierra52Week['Año']=dfrestotierra52Week['Año'].apply(año1)
dfrestotierra2021['Año']=dfrestotierra2021['Año'].apply(año2)
dfrestotierra2020['Año']=dfrestotierra2020['Año'].apply(año3)
dfrestotierra2019['Año']=dfrestotierra2019['Año'].apply(año4)
dfrestotierra2018['Año']=dfrestotierra2018['Año'].apply(año5)

dfrestodura52Week['Año']=dfrestodura52Week['Año'].apply(año1)
dfrestodura2021['Año']=dfrestodura2021['Año'].apply(año2)
dfrestodura2020['Año']=dfrestodura2020['Año'].apply(año3)
dfrestodura2019['Año']=dfrestodura2019['Año'].apply(año4)
dfrestodura2018['Año']=dfrestodura2018['Año'].apply(año5)

dfrestohierba52Week['Año']=dfrestohierba52Week['Año'].apply(año1)
dfrestohierba2021['Año']=dfrestohierba2021['Año'].apply(año2)
dfrestohierba2019['Año']=dfrestohierba2019['Año'].apply(año4)
dfrestohierba2018['Año']=dfrestohierba2018['Año'].apply(año5)

dfpresiontierra52Week['Año']=dfpresiontierra52Week['Año'].apply(año1)
dfpresiontierra2021['Año']=dfpresiontierra2021['Año'].apply(año2)
dfpresiontierra2020['Año']=dfpresiontierra2020['Año'].apply(año3)
dfpresiontierra2019['Año']=dfpresiontierra2019['Año'].apply(año4)
dfpresiontierra2018['Año']=dfpresiontierra2018['Año'].apply(año5)

dfpresiondura52Week['Año']=dfpresiondura52Week['Año'].apply(año1)
dfpresiondura2021['Año']=dfpresiondura2021['Año'].apply(año2)
dfpresiondura2020['Año']=dfpresiondura2020['Año'].apply(año3)
dfpresiondura2019['Año']=dfpresiondura2019['Año'].apply(año4)
dfpresiondura2018['Año']=dfpresiondura2018['Año'].apply(año5)

dfpresionhierba52Week['Año']=dfpresionhierba52Week['Año'].apply(año1)
dfpresionhierba2021['Año']=dfpresionhierba2021['Año'].apply(año2)
dfpresionhierba2019['Año']=dfpresionhierba2019['Año'].apply(año4)
dfpresionhierba2018['Año']=dfpresionhierba2018['Año'].apply(año5)

# %%
dfsaquetierra52Week['Superficie']=dfsaquetierra52Week['Superficie'].apply(superficie2)
dfsaquetierra2021['Superficie']=dfsaquetierra2021['Superficie'].apply(superficie2)
dfsaquetierra2020['Superficie']=dfsaquetierra2020['Superficie'].apply(superficie2)
dfsaquetierra2019['Superficie']=dfsaquetierra2019['Superficie'].apply(superficie2)
dfsaquetierra2018['Superficie']=dfsaquetierra2018['Superficie'].apply(superficie2)

dfsaquedura52Week['Superficie']=dfsaquedura52Week['Superficie'].apply(superficie1)
dfsaquedura2021['Superficie']=dfsaquedura2021['Superficie'].apply(superficie1)
dfsaquedura2020['Superficie']=dfsaquedura2020['Superficie'].apply(superficie1)
dfsaquedura2019['Superficie']=dfsaquedura2019['Superficie'].apply(superficie1)
dfsaquedura2018['Superficie']=dfsaquedura2018['Superficie'].apply(superficie1)

dfsaquehierba52Week['Superficie']=dfsaquehierba52Week['Superficie'].apply(superficie3)
dfsaquehierba2021['Superficie']=dfsaquehierba2021['Superficie'].apply(superficie3)
dfsaquehierba2019['Superficie']=dfsaquehierba2019['Superficie'].apply(superficie3)
dfsaquehierba2018['Superficie']=dfsaquehierba2018['Superficie'].apply(superficie3)

dfrestotierra52Week['Superficie']=dfrestotierra52Week['Superficie'].apply(superficie2)
dfrestotierra2021['Superficie']=dfrestotierra2021['Superficie'].apply(superficie2)
dfrestotierra2020['Superficie']=dfrestotierra2020['Superficie'].apply(superficie2)
dfrestotierra2019['Superficie']=dfrestotierra2019['Superficie'].apply(superficie2)
dfrestotierra2018['Superficie']=dfrestotierra2018['Superficie'].apply(superficie2)

dfrestodura52Week['Superficie']=dfrestodura52Week['Superficie'].apply(superficie1)
dfrestodura2021['Superficie']=dfrestodura2021['Superficie'].apply(superficie1)
dfrestodura2020['Superficie']=dfrestodura2020['Superficie'].apply(superficie1)
dfrestodura2019['Superficie']=dfrestodura2019['Superficie'].apply(superficie1)
dfrestodura2018['Superficie']=dfrestodura2018['Superficie'].apply(superficie1)

dfrestohierba52Week['Superficie']=dfrestohierba52Week['Superficie'].apply(superficie3)
dfrestohierba2021['Superficie']=dfrestohierba2021['Superficie'].apply(superficie3)
dfrestohierba2019['Superficie']=dfrestohierba2019['Superficie'].apply(superficie3)
dfrestohierba2018['Superficie']=dfrestohierba2018['Superficie'].apply(superficie3)

dfpresiontierra52Week['Superficie']=dfpresiontierra52Week['Superficie'].apply(superficie2)
dfpresiontierra2021['Superficie']=dfpresiontierra2021['Superficie'].apply(superficie2)
dfpresiontierra2020['Superficie']=dfpresiontierra2020['Superficie'].apply(superficie2)
dfpresiontierra2019['Superficie']=dfpresiontierra2019['Superficie'].apply(superficie2)
dfpresiontierra2018['Superficie']=dfpresiontierra2018['Superficie'].apply(superficie2)

dfpresiondura52Week['Superficie']=dfpresiondura52Week['Superficie'].apply(superficie1)
dfpresiondura2021['Superficie']=dfpresiondura2021['Superficie'].apply(superficie1)
dfpresiondura2020['Superficie']=dfpresiondura2020['Superficie'].apply(superficie1)
dfpresiondura2019['Superficie']=dfpresiondura2019['Superficie'].apply(superficie1)
dfpresiondura2018['Superficie']=dfpresiondura2018['Superficie'].apply(superficie1)

dfpresionhierba52Week['Superficie']=dfpresionhierba52Week['Superficie'].apply(superficie3)
dfpresionhierba2021['Superficie']=dfpresionhierba2021['Superficie'].apply(superficie3)
dfpresionhierba2019['Superficie']=dfpresionhierba2019['Superficie'].apply(superficie3)
dfpresionhierba2018['Superficie']=dfpresionhierba2018['Superficie'].apply(superficie3)

# %%
efectividadessaque=pd.concat([dfsaquetierra52Week,dfsaquedura52Week,dfsaquehierba52Week,
                              dfsaquetierra2021,dfsaquedura2021,dfsaquehierba2021,
                              dfsaquetierra2020,dfsaquedura2020,
                              dfsaquetierra2019,dfsaquedura2019,dfsaquehierba2019,
                              dfsaquetierra2018,dfsaquedura2018,dfsaquehierba2018],axis=0)

# %%
efectividadessaque = efectividadessaque.drop(columns=['Ranking_Efectividad_Saque'])

# %%
efectividadesresto=pd.concat([dfrestotierra52Week,dfrestodura52Week,dfrestohierba52Week,
                              dfrestotierra2021,dfrestodura2021,dfrestohierba2021,
                              dfrestotierra2020,dfrestodura2020,
                              dfrestotierra2019,dfrestodura2019,dfrestohierba2019,
                              dfrestotierra2018,dfrestodura2018,dfrestohierba2018],axis=0)

# %%
efectividadesresto = efectividadesresto.drop(columns=['Ranking_Efectividad_Resto'])

# %%
efectividadespresion=pd.concat([dfpresiontierra52Week,dfpresiondura52Week,dfpresionhierba52Week,
                                dfpresiontierra2021,dfpresiondura2021,dfpresionhierba2021,
                                dfpresiontierra2020,dfpresiondura2020,
                                dfpresiontierra2019,dfpresiondura2019,dfpresionhierba2019,
                                dfpresiontierra2018,dfpresiondura2018,dfpresionhierba2018],axis=0)

# %%
efectividadespresion = efectividadespresion.drop(columns=['Ranking_Efectividad_Bajo_Presion'])

# %%
efectividadessaque.to_csv('../data/EfecSaque.csv', index=False)
efectividadesresto.to_csv('../data/EfecResto.csv', index=False)
efectividadespresion.to_csv('../data/EfecPresion.csv', index=False)

# %%
efectividadespresion.head()
# Out:
#               Jugador  Efectividad_bajo_presion  Break_Points_Covertidos_pct  \
# 0    Alexander Zverev                     283.9                         45.1
# 1      Frances Tiafoe                     252.9                         39.3
# 2         Marin Cilic                     252.5                         44.4
# 3  Stefanos Tsitsipas                     250.3                         48.4
# 4        Daniel Evans                     247.9                         44.0
#
#    Break_Points_Salvados_pct  Tie_Break_Ganados_pct  \
# 0                       58.8                  100.0
# 1                       63.6                   66.7
# 2                       65.2                  100.0
# 3                       57.4                   66.7
# 4                       61.0                   42.9
#
#    Victorias_Sets_Definitivos_pct   Año Superficie
# 0                            80.0  2022       Clay
# 1                            83.3  2022       Clay
# ...
